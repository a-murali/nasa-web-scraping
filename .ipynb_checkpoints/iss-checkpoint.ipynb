# %%
import requests

url = "http://api.open-notify.org/iss-now.json" #https://isstracker.spaceflight.esa.int/
response = requests.get(url)
data = response.json()

latitude = data['iss_position']['latitude']
longitude = data['iss_position']['longitude']

print(f"Latitude: {latitude}")
print(f"Longitude: {longitude}")
# Out:
# Latitude: -51.6217
# Longitude: 121.0315

# %%
import requests
import time
import folium

m = folium.Map(location=[0, 0], zoom_start=2)
trajectory = []
for i in range(1000):
    url = "http://api.open-notify.org/iss-now.json" #https://isstracker.spaceflight.esa.int/
    response = requests.get(url)
    data = response.json()

    latitude = float(data['iss_position']['latitude'])
    longitude = float(data['iss_position']['longitude'])
    
    trajectory.append([latitude, longitude])
    time.sleep(10)
    
# print(trajectory)
# # create a line feature from the trajectory data
# line = folium.features.PolyLine(locations=trajectory, weight=5, color='blue')

# # create a marker feature for each point in the trajectory
# markers = [folium.Marker(location=point) for point in trajectory]

# # add the line and markers to the map
# line.add_to(m)
# for marker in markers:
#     marker.add_to(m)

# # display the map
# m

# create a curve feature from the trajectory data
curve = folium.plugins.AntPath(locations=trajectory, weight=5, color='blue', delay=1000)

# create a marker feature for each point in the trajectory
markers = [folium.Marker(location=point) for point in trajectory]

# add the curve and markers to the map
curve.add_to(m)
for marker in markers:
    marker.add_to(m)

# display the map
m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_371/3437781568.py in <module>
#      14
#      15     trajectory.append([latitude, longitude])
# ---> 16     time.sleep(10)
#      17
#      18 # print(trajectory)
#
# KeyboardInterrupt:

# %%
import folium
from folium.plugins import TimestampedGeoJson

# create a map centered at (0,0)
m = folium.Map(location=[0, 0], zoom_start=2)

# define some latitude and longitude values for the trajectory
trajectory = [
    {'time': '2022-01-01', 'lat': 37.7749, 'lon': -122.4194},
    {'time': '2022-02-01', 'lat': 40.7128, 'lon': -74.0060},
    {'time': '2022-03-01', 'lat': 51.5074, 'lon': -0.1278},
    {'time': '2022-04-01', 'lat': 35.6895, 'lon': 139.6917},
    {'time': '2022-05-01', 'lat': -33.8688, 'lon': 151.2093},
]

# create a GeoJSON feature collection from the trajectory data
features = []
for point in trajectory:
    features.append({
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': [point['lon'], point['lat']]
        },
        'properties': {
            'time': point['time']
        }
    })

# create a TimestampedGeoJson object from the feature collection
ts_geojson = TimestampedGeoJson({'type': 'FeatureCollection', 'features': features}, period='P1M', add_last_point=True)

# add the TimestampedGeoJson object to the map
ts_geojson.add_to(m)

# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
